# %%
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt  
from sklearn.cluster import KMeans 
# %matplotlib  inline 
df = pd.read_csv('single_family_home_values.csv') # zillow

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df[["bathrooms","squareFootage"]].corr())

# %%
df[["bathrooms","squareFootage"]].cov()
# Out:
#                 bathrooms  squareFootage
# bathrooms        1.360206     779.050745
# squareFootage  779.050745  689956.162391
